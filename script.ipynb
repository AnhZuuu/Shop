-- %% [markdown]
-- # [UserManagement]

-- %%
USE [master]
GO

-- %%
/****** Object:  Database [UserManagement]    Script Date: 7/6/2023 1:17:26 AM ******/
CREATE DATABASE [UserManagement]
 CONTAINMENT = NONE
 ON  PRIMARY 
( NAME = N'UserManagement', FILENAME = N'D:\University\MSSQL14.SQLEXPRESS\MSSQL\DATA\UserManagement.mdf' , SIZE = 8192KB , MAXSIZE = UNLIMITED, FILEGROWTH = 65536KB )
 LOG ON 
( NAME = N'UserManagement_log', FILENAME = N'D:\University\MSSQL14.SQLEXPRESS\MSSQL\DATA\UserManagement_log.ldf' , SIZE = 8192KB , MAXSIZE = 2048GB , FILEGROWTH = 65536KB )
GO
ALTER DATABASE [UserManagement] SET COMPATIBILITY_LEVEL = 140
GO
IF (1 = FULLTEXTSERVICEPROPERTY('IsFullTextInstalled'))
begin
EXEC [UserManagement].[dbo].[sp_fulltext_database] @action = 'enable'
end
GO
ALTER DATABASE [UserManagement] SET ANSI_NULL_DEFAULT OFF 
GO
ALTER DATABASE [UserManagement] SET ANSI_NULLS OFF 
GO
ALTER DATABASE [UserManagement] SET ANSI_PADDING OFF 
GO
ALTER DATABASE [UserManagement] SET ANSI_WARNINGS OFF 
GO
ALTER DATABASE [UserManagement] SET ARITHABORT OFF 
GO
ALTER DATABASE [UserManagement] SET AUTO_CLOSE ON 
GO
ALTER DATABASE [UserManagement] SET AUTO_SHRINK OFF 
GO
ALTER DATABASE [UserManagement] SET AUTO_UPDATE_STATISTICS ON 
GO
ALTER DATABASE [UserManagement] SET CURSOR_CLOSE_ON_COMMIT OFF 
GO
ALTER DATABASE [UserManagement] SET CURSOR_DEFAULT  GLOBAL 
GO
ALTER DATABASE [UserManagement] SET CONCAT_NULL_YIELDS_NULL OFF 
GO
ALTER DATABASE [UserManagement] SET NUMERIC_ROUNDABORT OFF 
GO
ALTER DATABASE [UserManagement] SET QUOTED_IDENTIFIER OFF 
GO
ALTER DATABASE [UserManagement] SET RECURSIVE_TRIGGERS OFF 
GO
ALTER DATABASE [UserManagement] SET  ENABLE_BROKER 
GO
ALTER DATABASE [UserManagement] SET AUTO_UPDATE_STATISTICS_ASYNC OFF 
GO
ALTER DATABASE [UserManagement] SET DATE_CORRELATION_OPTIMIZATION OFF 
GO
ALTER DATABASE [UserManagement] SET TRUSTWORTHY OFF 
GO
ALTER DATABASE [UserManagement] SET ALLOW_SNAPSHOT_ISOLATION OFF 
GO
ALTER DATABASE [UserManagement] SET PARAMETERIZATION SIMPLE 
GO
ALTER DATABASE [UserManagement] SET READ_COMMITTED_SNAPSHOT OFF 
GO
ALTER DATABASE [UserManagement] SET HONOR_BROKER_PRIORITY OFF 
GO
ALTER DATABASE [UserManagement] SET RECOVERY SIMPLE 
GO
ALTER DATABASE [UserManagement] SET  MULTI_USER 
GO
ALTER DATABASE [UserManagement] SET PAGE_VERIFY CHECKSUM  
GO
ALTER DATABASE [UserManagement] SET DB_CHAINING OFF 
GO
ALTER DATABASE [UserManagement] SET FILESTREAM( NON_TRANSACTED_ACCESS = OFF ) 
GO
ALTER DATABASE [UserManagement] SET TARGET_RECOVERY_TIME = 60 SECONDS 
GO
ALTER DATABASE [UserManagement] SET DELAYED_DURABILITY = DISABLED 
GO
ALTER DATABASE [UserManagement] SET QUERY_STORE = OFF
GO

-- %% [markdown]
-- # [dbo].[tblCartDetails]

-- %%
USE [UserManagement]
GO

-- %%
/****** Object:  Table [dbo].[tblCartDetails]    Script Date: 7/6/2023 1:17:27 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[tblCartDetails](
	[cartDetailID] [int] IDENTITY(1,1) NOT NULL,
	[cartID] [int] NULL,
	[productID] [nvarchar](50) NULL,
	[price] [float] NOT NULL,
	[quantity] [int] NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[cartDetailID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[tblCarts]

-- %%
/****** Object:  Table [dbo].[tblCarts]    Script Date: 7/6/2023 1:17:27 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[tblCarts](
	[cartID] [int] IDENTITY(1,1) NOT NULL,
	[userID] [nvarchar](50) NOT NULL,
	[total] [float] NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[cartID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[tblOrderDetails]

-- %%
/****** Object:  Table [dbo].[tblOrderDetails]    Script Date: 7/6/2023 1:17:27 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[tblOrderDetails](
	[orderDetailID] [int] IDENTITY(1,1) NOT NULL,
	[orderID] [int] NULL,
	[productID] [nvarchar](50) NULL,
	[price] [float] NOT NULL,
	[quantity] [int] NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[orderDetailID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[tblOrders]

-- %%
/****** Object:  Table [dbo].[tblOrders]    Script Date: 7/6/2023 1:17:27 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[tblOrders](
	[orderID] [int] IDENTITY(1,1) NOT NULL,
	[userID] [nvarchar](50) NOT NULL,
	[date] [date] NOT NULL,
	[total] [float] NOT NULL,
	[status] [int] NULL,
PRIMARY KEY CLUSTERED 
(
	[orderID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[tblProducts]

-- %%
/****** Object:  Table [dbo].[tblProducts]    Script Date: 7/6/2023 1:17:27 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[tblProducts](
	[productID] [nvarchar](50) NOT NULL,
	[productName] [nvarchar](50) NOT NULL,
	[price] [float] NOT NULL,
	[quantityInStock] [int] NOT NULL,
	[imageSrc] [nvarchar](50) NULL,
	[description] [nvarchar](255) NULL,
	[manufacturer] [nvarchar](50) NULL,
	[warranty] [int] NULL,
	[color] [nvarchar](20) NULL,
	[type] [nvarchar](50) NULL,
PRIMARY KEY CLUSTERED 
(
	[productID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[tblUsers]

-- %%
/****** Object:  Table [dbo].[tblUsers]    Script Date: 7/6/2023 1:17:27 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[tblUsers](
	[userID] [nvarchar](50) NOT NULL,
	[fullName] [nvarchar](50) NULL,
	[password] [nvarchar](50) NULL,
	[roleID] [nvarchar](50) NULL,
	[status] [bit] NULL,
 CONSTRAINT [PK_tblUsers] PRIMARY KEY CLUSTERED 
(
	[userID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[tblOrderDetails]

-- %%
SET IDENTITY_INSERT [dbo].[tblOrderDetails] ON 
INSERT [dbo].[tblOrderDetails] ([orderDetailID], [orderID], [productID], [price], [quantity]) VALUES (1, 2, N'T01', 25, 1)
INSERT [dbo].[tblOrderDetails] ([orderDetailID], [orderID], [productID], [price], [quantity]) VALUES (4, 5, N'T01', 25, 1)
INSERT [dbo].[tblOrderDetails] ([orderDetailID], [orderID], [productID], [price], [quantity]) VALUES (5, 6, N'T01', 25, 1)
INSERT [dbo].[tblOrderDetails] ([orderDetailID], [orderID], [productID], [price], [quantity]) VALUES (6, 6, N'T03', 40, 10)
INSERT [dbo].[tblOrderDetails] ([orderDetailID], [orderID], [productID], [price], [quantity]) VALUES (7, 7, N'T01', 25, 1)
INSERT [dbo].[tblOrderDetails] ([orderDetailID], [orderID], [productID], [price], [quantity]) VALUES (8, 7, N'T03', 40, 10)
INSERT [dbo].[tblOrderDetails] ([orderDetailID], [orderID], [productID], [price], [quantity]) VALUES (9, 8, N'T01', 25, 1)
INSERT [dbo].[tblOrderDetails] ([orderDetailID], [orderID], [productID], [price], [quantity]) VALUES (10, 9, N'T01', 25, 1)
INSERT [dbo].[tblOrderDetails] ([orderDetailID], [orderID], [productID], [price], [quantity]) VALUES (11, 10, N'T01', 2450, 1)
SET IDENTITY_INSERT [dbo].[tblOrderDetails] OFF
GO

-- %% [markdown]
-- # [dbo].[tblOrders]

-- %%
SET IDENTITY_INSERT [dbo].[tblOrders] ON 
INSERT [dbo].[tblOrders] ([orderID], [userID], [date], [total], [status]) VALUES (2, N'hoadnt', CAST(N'2023-06-20' AS Date), 25, 0)
INSERT [dbo].[tblOrders] ([orderID], [userID], [date], [total], [status]) VALUES (5, N'hoadnt', CAST(N'2023-06-20' AS Date), 25, 0)
INSERT [dbo].[tblOrders] ([orderID], [userID], [date], [total], [status]) VALUES (6, N'hoadnt', CAST(N'2023-06-22' AS Date), 425, 1)
INSERT [dbo].[tblOrders] ([orderID], [userID], [date], [total], [status]) VALUES (7, N'hoadnt', CAST(N'2023-06-22' AS Date), 425, 0)
INSERT [dbo].[tblOrders] ([orderID], [userID], [date], [total], [status]) VALUES (8, N'hoadnt', CAST(N'2023-06-22' AS Date), 25, 1)
INSERT [dbo].[tblOrders] ([orderID], [userID], [date], [total], [status]) VALUES (9, N'hoadnt', CAST(N'2023-06-22' AS Date), 25, -1)
INSERT [dbo].[tblOrders] ([orderID], [userID], [date], [total], [status]) VALUES (10, N'hoadnt', CAST(N'2023-07-05' AS Date), 2450, 0)
SET IDENTITY_INSERT [dbo].[tblOrders] OFF
GO

-- %% [markdown]
-- # [dbo].[tblProducts]

-- %%
INSERT [dbo].[tblProducts] ([productID], [productName], [price], [quantityInStock], [imageSrc], [description], [manufacturer], [warranty], [color], [type]) VALUES (N'T01', N'Razer Kraken V3', 245, 99, N'images/products/RazerKrakenV3.png', NULL, N'Razer', 24, N'black', N'Over-ear, wire')
INSERT [dbo].[tblProducts] ([productID], [productName], [price], [quantityInStock], [imageSrc], [description], [manufacturer], [warranty], [color], [type]) VALUES (N'T02', N'Razer Hammerhead True Wireless', 179, 150, N'images/products/zerHammerhead.png', NULL, N'Razer', 24, N'black', N'In-ear, wireless')
INSERT [dbo].[tblProducts] ([productID], [productName], [price], [quantityInStock], [imageSrc], [description], [manufacturer], [warranty], [color], [type]) VALUES (N'T03', N'Asus ROG Cetra II Core', 40, 5, N'images/products/rogCetra.png', NULL, N'Asus', 24, N'black', N'In-ear, wire')
INSERT [dbo].[tblProducts] ([productID], [productName], [price], [quantityInStock], [imageSrc], [description], [manufacturer], [warranty], [color], [type]) VALUES (N'T04', N'Corsair HS80 RGB Wireless', 100, 75, N'images/products/ledRgbWireless.png', NULL, N'Corsair', 24, N'silver', N'over-ear, wireless')
INSERT [dbo].[tblProducts] ([productID], [productName], [price], [quantityInStock], [imageSrc], [description], [manufacturer], [warranty], [color], [type]) VALUES (N'T05', N'Logitech G Pro X League Of Legends', 120, 22, N'images/products/logitechGProX.png', NULL, N'Logitech', 24, N'blue', N'over-ear, wire')
GO

-- %% [markdown]
-- # [dbo].[tblUsers]

-- %%
INSERT [dbo].[tblUsers] ([userID], [fullName], [password], [roleID], [status]) VALUES (N'admin', N'toi la admin', N'1', N'AD', 1)
INSERT [dbo].[tblUsers] ([userID], [fullName], [password], [roleID], [status]) VALUES (N'admin01', N'admin 01', N'123', N'US', NULL)
INSERT [dbo].[tblUsers] ([userID], [fullName], [password], [roleID], [status]) VALUES (N'admin3', N'admin 03', N'1', N'US', NULL)
INSERT [dbo].[tblUsers] ([userID], [fullName], [password], [roleID], [status]) VALUES (N'Hoadnt', N'Hoa Doan', N'1', N'US', 1)
INSERT [dbo].[tblUsers] ([userID], [fullName], [password], [roleID], [status]) VALUES (N'SE130363', N'Ngo Ha Tri Bao', N'1', N'AD', 1)
INSERT [dbo].[tblUsers] ([userID], [fullName], [password], [roleID], [status]) VALUES (N'SE140103', N'Phuoc Ha', N'1', N'US', 1)
INSERT [dbo].[tblUsers] ([userID], [fullName], [password], [roleID], [status]) VALUES (N'SE140130', N'Tam Tran', N'1', N'US', 1)
INSERT [dbo].[tblUsers] ([userID], [fullName], [password], [roleID], [status]) VALUES (N'SE140201', N'PHAM HOANG TU', N'1', N'AD', 1)
GO

-- %% [markdown]
-- # [FK__tblCartDe__produ__7C4F7684]

-- %%
ALTER TABLE [dbo].[tblCartDetails]  WITH CHECK ADD FOREIGN KEY([productID])
REFERENCES [dbo].[tblProducts] ([productID])
GO

-- %% [markdown]
-- # [FK_tblCartDetails_tblCarts]

-- %%
ALTER TABLE [dbo].[tblCartDetails]  WITH CHECK ADD  CONSTRAINT [FK_tblCartDetails_tblCarts] FOREIGN KEY([cartID])
REFERENCES [dbo].[tblCarts] ([cartID])
GO
ALTER TABLE [dbo].[tblCartDetails] CHECK CONSTRAINT [FK_tblCartDetails_tblCarts]
GO

-- %% [markdown]
-- # [FK__tblCarts__userID__76969D2E]

-- %%
ALTER TABLE [dbo].[tblCarts]  WITH CHECK ADD FOREIGN KEY([userID])
REFERENCES [dbo].[tblUsers] ([userID])
GO

-- %% [markdown]
-- # [FK__tblOrderD__produ__66603565]

-- %%
ALTER TABLE [dbo].[tblOrderDetails]  WITH CHECK ADD FOREIGN KEY([productID])
REFERENCES [dbo].[tblProducts] ([productID])
GO

-- %% [markdown]
-- # [FK_tblOrderDetails_tblOrders]

-- %%
ALTER TABLE [dbo].[tblOrderDetails]  WITH CHECK ADD  CONSTRAINT [FK_tblOrderDetails_tblOrders] FOREIGN KEY([orderID])
REFERENCES [dbo].[tblOrders] ([orderID])
GO
ALTER TABLE [dbo].[tblOrderDetails] CHECK CONSTRAINT [FK_tblOrderDetails_tblOrders]
GO

-- %% [markdown]
-- # [FK__tblOrders__userI__06CD04F7]

-- %%
ALTER TABLE [dbo].[tblOrders]  WITH CHECK ADD FOREIGN KEY([userID])
REFERENCES [dbo].[tblUsers] ([userID])
GO

-- %% [markdown]
-- # [UserManagement]

-- %%
USE [master]
GO

-- %%
ALTER DATABASE [UserManagement] SET  READ_WRITE 
GO
